# %%
import sys
import os

try:
    import Vips
    import urllib
except:
    os.chdir('../')
    sys.path.append('database/chunk/VipsPython/Vips/')
    import Vips
    import urllib

# %%
def main():
    vips = Vips.Vips(urllib.parse.unquote("https://www.korea.kr/news/policyNewsView.do?newsId=148920123&pWise=main&pWiseMain=A1", encoding="utf-8"))
    b = vips.parse()
    print(b)
    print()
    
main()
# Out:
# -----------------------------Getting Screenshot------------------------------------
# getting dimensions...
# loading...
# getting screenshot...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/minsu/Desktop/Projects/YAI/YAICONVALLEY/OpenAI_SKT/openai_skt/tutorials/vips.ipynb 셀 2 line 7
#       <a href='vscode-notebook-cell:/Users/minsu/Desktop/Projects/YAI/YAICONVALLEY/OpenAI_SKT/openai_skt/tutorials/vips.ipynb#W1sZmlsZQ%3D%3D?line=3'>4</a>     print(b)
#       <a href='vscode-notebook-cell:/Users/minsu/Desktop/Projects/YAI/YAICONVALLEY/OpenAI_SKT/openai_skt/tutorials/vips.ipynb#W1sZmlsZQ%3D%3D?line=4'>5</a>     print()
# ----> <a href='vscode-notebook-cell:/Users/minsu/Desktop/Projects/YAI/YAICONVALLEY/OpenAI_SKT/openai_skt/tutorials/vips.ipynb#W1sZmlsZQ%3D%3D?line=6'>7</a> main()
#
# ...
